# %%
import os
import numpy as np
from RegionFilter import doesPassFilter
import cv2
from matplotlib import pyplot as plt

# %%
test_dir = 'test_images'
test_files = os.listdir(test_dir)    
hues, sats, vals = [], [], []

for image in os.listdir(test_dir):
    path = f'{test_dir}/{image}'
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    if '/x' in path and not doesPassFilter(img):
        print('filter works for x')
    elif '/o' in path and doesPassFilter(img):
        print('filter works for o')
    else:
        print(path, doesPassFilter(img))
# Out:
# filter works for x
# filter works for o
# filter works for o
# filter works for o
# filter works for x
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# filter works for x
# filter works for o
# filter works for o
# filter works for o
# filter works for x
# filter works for x
# filter works for x
# filter works for x
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# filter works for x
# filter works for o
# filter works for o
# filter works for x
# filter works for x
# filter works for x
# filter works for o
# filter works for o
# filter works for o
# filter works for x
# filter works for x
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# test_images/x (40).png True
# filter works for x
# test_images/x (36).png True
# filter works for o
# filter works for o
# filter works for o
# filter works for o
# ...
